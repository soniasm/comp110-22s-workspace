# %% [markdown]
# # Analysis for Continuous Improvement
#
# Author Name: Sonia Patel
#
# 9-digit PID: 730392257
#
# Continuous Improvement embraces a belief there is _always room to make things better_. It is a mindset and process we value and practice in this course. In this assignment, you are able to practice continuous improvement and contribute to the design ideas of the course.
#
# ## Brainstorming Ideas
#
# Reflect on your personal experiences and observations in COMP110 and **brainstorm modifications to the course that _create value_ beyond its current design**. When brainstorming, try not to be critical of the ideas you come up with regarding scale, stakeholders impacted, or for any other reasons. In the markdown cell below, brainstorm 3 to 5 ideas you think would create value for you.
#
# Each brainstormed idea should state a. the suggested change or addition, b. what the expected value created, and c. which specific stakeholders would benefit.  If helpful, expand on the following template "The course should (state idea here) because it will (state value created here) for (insert stakeholders here)."
#
# Example A: "The course should use only examples from psychology experiments because it will be more relevant for students who are psychology majors."
#
# Example B: "The course should not have post-lesson questions because they are not useful for most students in the class."

# %% [markdown]
# ### Part 1. Creative Ideation
#
# 1. The course should allow students to use past practice quizzes to study for quizzes because they allow extra practice for students enrolled in the class.
# 2. The course should move slower because it allows students who are enrolled to have more time to understand content.
# 3. The course should change office hour appointments from 15 minutes to 30 minutes because it allows instructional staff more time to answer student questions more thoroughly.
# 4. The course should offer practice programming exercises that are not graded because it provides extra practice to students enrolled who try to come up with examples in code but need extra practice.
# 5. The course should offer guided notes for class videos and topics covered in lecture because it helps students better understand the concepts they are expected to learn.

# %% [markdown]
# ## Connecting with Available Data
#
# The data you have available for this analysis is limited to the anonymized course survey you and your peers filled out a few weeks ago. The data is found in the `survey.csv` file in this exercise directory. Each row represents an individual survey response. Each column has a description which can be found on the project write-up here: <https://22s.comp110.com/exercises/ex08.html>
#
# Review the list of available data and identify which one of your ideas _does not_, or is _least likely to_, have relevant data to support the analysis of your idea to create value. In the box below, identify which of your ideas lacks data and suggest how we might be able to collect this data in the future. One aspect of _continuous improvement_ is trying to avoid "tunnel vision" where possible improvements are not considered because there is no data available to analyze it. Identifying new data sources can unlock improvements!

# %% [markdown]
# ### Part 2. Identifying Missing Data
#
# 1. Idea without sufficient data to analyze:  The course should allow students to use past practice quizzes to study for quizzes because they allow extra practice for students enrolled in the class.
#
# 2. Suggestion for how to collect data to support this idea in the future: We can collect data on whether or not students prefer practice problems to rewatching lectures to see if students would use quizzes from previous years to aid in their studying. We can also measure how effective the practice problems already given are in preparing for quizzes, according to students.

# %% [markdown]
# ## Choosing an Idea to Analyze
#
# Consider those of your ideas which _do_ seem likely to have relevant data to analyze. If none of your ideas do, spend a few minutes and brainstorm another idea or two with the added connection of data available on hand and add those ideas to your brainstormed ideas list.
#
# Select the one idea which you believe is _most valuable_ to analyze relative to the others and has data to support the analysis of. In the markdown cell for Part 3 below, identify the idea you are exploring and articulate why you believe it is most valuable (e.g. widest impact, biggest opportunity for improvement, simplest change for significant improvement, and so on).

# %% [markdown]
# ### Part 3. Choosing Your Analysis
#
# 1. Idea to analyze with available data: The course should offer practice programming exercises that are not graded because it provides extra practice to students enrolled who may have trouble coming up with their own examples.
#
# 2. This idea is more valuable than the others brainstormed because: We do not currently have this idea implemented in class, besides Hack 110. People are not always sure how to get extra practice programming specifically when they are not doing the exercises for credit, and small programming exercises could help with that. I chose this over the other ideas because I think it would add the most value to the class. Although changing how fast the course moves and office hour times is useful, this is something likely more realistic that can be implemented. I also chose this idea because it can be easily studied through the data provided, using the data about programming exercise effectiveness and whether students can come up with their own examples.

# %% [markdown]
# ## Your Analysis
#
# Before you begin analysis, a reminder that we do not expect the data to support everyone's ideas and you can complete this exercise for full credit even if the data does not clearly support your suggestion or even completely refutes it. What we are looking for is a logical attempt to explore the data using the techniques you have learned up until now in a way that _either_ supports, refutes, or does not have a clear result and then to reflect on your findings after the analysis.
#
# Using the utility functions you created for the previous exercise, you will continue with your analysis in the following part. Before you begin, refer to the rubric on the technical expectations of this section in the exercise write-up.
#
# In this section, you are expected to interleave code and markdown cells such that for each step of your analysis you are starting with an English description of what you are planning to do next in a markdown cell, followed by a Python cell that performs that step of the analysis.

# %% [markdown]
# ### Part 4. Analysis
#
# We begin by changing some settings in the notebook to automatically reload changes to imported files.

# %%
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# We continue by importing the helper functions from `data_utils`.

# %%
from data_utils import read_csv_rows, column_values, columnar, head, select, count, values

# %% [markdown]
# Next, use the `read_csv_rows` function to read the number of columns, rows, and name all the columns.

# %%
SURVEY_DATA_CSV_FILE_PATH: str = "../../data/survey.csv"

data_rows: list[dict[str, str]] = read_csv_rows(SURVEY_DATA_CSV_FILE_PATH)

if len(data_rows) == 0:
    print("Go implement read_csv_rows in data_utils.py")
    print("Be sure to save your work before re-evaluating this cell!")
else:
    print(f"{len(data_rows)} rows")
    print(f"{len(data_rows[0].keys())} columns")
    print(f"Columns names: {data_rows[0].keys()}")
# Out:
# 620 rows
# 35 columns
# Columns names: dict_keys(['row', 'year', 'unc_status', 'comp_major', 'primary_major', 'data_science', 'prereqs', 'prior_exp', 'ap_principles', 'ap_a', 'other_comp', 'prior_time', 'languages', 'hours_online_social', 'hours_online_work', 'lesson_time', 'sync_perf', 'all_sync', 'flipped_class', 'no_hybrid', 'own_notes', 'own_examples', 'oh_visits', 'ls_effective', 'lsqs_effective', 'programming_effective', 'qz_effective', 'oh_effective', 'tutoring_effective', 'pace', 'difficulty', 'understanding', 'interesting', 'valuable', 'would_recommend'])

# %% [markdown]
# Next, use `columnar` function to create a column-oriented table, which will be useful in the next function.

# %%
data_cols: dict[str, list[str]] = columnar(data_rows)

if len(data_cols.keys()) == 0:
    print("Complete your implementation of columnar in data_utils.py")
    print("Be sure to follow the guidelines above and save your work before re-evaluating!")
else:
    print(f"{len(data_cols.keys())} columns")
    print(f"{len(data_cols['row'])} rows")
    print(f"Columns names: {data_cols.keys()}")
# Out:
# 35 columns
# 620 rows
# Columns names: dict_keys(['row', 'year', 'unc_status', 'comp_major', 'primary_major', 'data_science', 'prereqs', 'prior_exp', 'ap_principles', 'ap_a', 'other_comp', 'prior_time', 'languages', 'hours_online_social', 'hours_online_work', 'lesson_time', 'sync_perf', 'all_sync', 'flipped_class', 'no_hybrid', 'own_notes', 'own_examples', 'oh_visits', 'ls_effective', 'lsqs_effective', 'programming_effective', 'qz_effective', 'oh_effective', 'tutoring_effective', 'pace', 'difficulty', 'understanding', 'interesting', 'valuable', 'would_recommend'])

# %% [markdown]
# Next, use `head` function to make a table of all the data - this particular code shows the first 25 rows of data.

# %%
from tabulate import tabulate

data_cols_head: dict[str, list[str]] = head(data_cols, 25)

if len(data_cols_head.keys()) != len(data_cols.keys()) or len(data_cols_head["row"]) != 25:
    print("Complete your implementation of columnar in data_utils.py")
    print("Be sure to follow the guidelines above and save your work before re-evaluating!")

tabulate(data_cols_head, data_cols_head.keys(), "html")
# Out:
# '<table>\n<thead>\n<tr><th style="text-align: right;">  row</th><th style="text-align: right;">  year</th><th>unc_status                 </th><th>comp_major  </th><th>primary_major                </th><th>data_science  </th><th>prereqs                                                                       </th><th>prior_exp                   </th><th>ap_principles  </th><th>ap_a  </th><th>other_comp                      </th><th>prior_time                  </th><th>languages                                                                 </th><th>hours_online_social  </th><th>hours_online_work  </th><th style="text-align: right;">  lesson_time</th><th style="text-align: right;">  sync_perf</th><th style="text-align: right;">  all_sync</th><th style="text-align: right;">  flipped_class</th><th style="text-align: right;">  no_hybrid</th><th style="text-align: right;">  own_notes</th><th style="text-align: right;">  own_examples</th><th style="text-align: right;">  oh_visits</th><th styl
# ...

# %% [markdown]
# Next, use `select` function to create a table of only the columns programming_effective and own_examples, the two variables being studied

# %%
from data_utils import select

selected_data: dict[str, list[str]] = select(data_cols, ["programming_effective", "own_examples"])

tabulate(head(selected_data, 25), selected_data.keys(), "html")
# Out:
# '<table>\n<thead>\n<tr><th style="text-align: right;">  programming_effective</th><th style="text-align: right;">  own_examples</th></tr>\n</thead>\n<tbody>\n<tr><td style="text-align: right;">                      7</td><td style="text-align: right;">             4</td></tr>\n<tr><td style="text-align: right;">                      5</td><td style="text-align: right;">             4</td></tr>\n<tr><td style="text-align: right;">                      7</td><td style="text-align: right;">             7</td></tr>\n<tr><td style="text-align: right;">                      5</td><td style="text-align: right;">             5</td></tr>\n<tr><td style="text-align: right;">                      6</td><td style="text-align: right;">             3</td></tr>\n<tr><td style="text-align: right;">                      7</td><td style="text-align: right;">             5</td></tr>\n<tr><td style="text-align: right;">                      7</td><td style="text-align: right;">             7</td></tr>\n
# ...

# %% [markdown]
# Next, use `count` function to count how many times each number appears in the input list for the columns programming_effective and own_examples.

# %%
programming_effective_count: dict[str, int] = count(selected_data["programming_effective"])
print(f"programming_effective_counts: {programming_effective_count}")

own_examples_count: dict[str, int] = count(selected_data["own_examples"])
print(f"own_examples_counts: {own_examples_count}")
# Out:
# programming_effective_counts: {'7': 324, '5': 82, '6': 154, '4': 34, '2': 11, '3': 10, '1': 5}
# own_examples_counts: {'4': 123, '7': 103, '5': 161, '3': 77, '2': 32, '1': 14, '6': 110}

# %% [markdown]
# Next, use `values` to find the amount of high values (6s and 7s) and the amount of low values (2s and 1s) in the survey data for programmming_effective and own_examples columns.

# %%
programming_effective_values: str = values(programming_effective_count)
print(f"programming_effective_values: {programming_effective_values}")
own_examples_values: str = values(own_examples_count)
print(f"own_examples_values: {own_examples_values}")
# Out:
# programming_effective_values: high_value: 478; low_value: 16
# own_examples_values: high_value: 213; low_value: 46

# %% [markdown]
# Next, create chart of data comparing how many high values to low values there are in the relevant categories for a visual representation.

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt

labels = ['high rating', 'low rating']
y_pos = [0, 1]  # the order the labels will be arranged in bar chart
performance = [478, 16]

plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, labels)
plt.ylabel('Number of Students')
plt.title('Programming exercise Effectiveness Rating')

plt.show()

labels = ['often comes up with example', 'rarely comes up with example']
y_pos = [0, 1]  # the order the labels will be arranged in bar chart
performance = [213, 46]

plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, labels)
plt.ylabel('Number of Students')
plt.title('Whether or Not Students come up with their own examples.')

plt.show()

# %% [markdown]
# ## Conclusion
#
# In the following markdown cell, write a reflective conclusion given the analysis you performed and identify recommendations.
#
# If your analysis of the data supports your idea, state your recommendation for the change and summarize the data analysys results you found which support it. Additionally, describe any extensions or refinements to this idea which might be explored further. Finally, discuss the potential costs, trade-offs, or stakeholders who may be negatively impacted by this proposed change.

# %% [markdown]
# ### Part 5. Conclusion
#
# My analysis supports my data as it shows programming exercises are useful for students to understand concepts better, and it also reveals that students do put in the work to come up with their own examples. Even so, there is an overwhelming majority that believes the programming exercises are very valuable. I would recommend that, for every few lessons, a mini-practice coding exercises is added to the materials. It can be shorter than our actual assignments, and would not be for a class grade, just for extra practice. This way, students who feel like they need extra practice can use these exercises to help them. This idea can extend to challenge coding exercises as well, for students who dont feel the practice they are getting is challenging enough.
# Some costs to this include the extra time it would take for instructional staff to write the exercises and to implement a section on gradescope to autograde the exercise and check the student's work. This also uses more space and could be confusing for students to try to figure out which is a practice exercise and which is for a real course grade, negatively impacting the professor and instructional staff, who may have to field emails from confused students. However, I do believe these problems are easily solvable with clear instructions and headings, and with the understanding that the practice programming exercises are meant to be shorter versions of the real programming exercises.
